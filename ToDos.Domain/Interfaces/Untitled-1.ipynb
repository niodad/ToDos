# %%
from docx import Document
from docx.shared import Pt
from docx.enum.style import WD_STYLE_TYPE

# Maak een nieuw Word-document
doc = Document()
doc.add_heading('Inpakchecklist – Man | Bali & Lombok | 1–20 juli', level=0)

# Definieer checklistcategorieën en items
checklist = {
    "👕 KLEDING": [
        "4x T-shirts (licht & sneldrogend)",
        "2x Tanktops of mouwloze hemden",
        "2x Korte broeken",
        "1x Luchtige lange broek",
        "1x Luchtig (langmouw) overhemd",
        "1x Lichte trui of vest",
        "1x Regenjasje of poncho",
        "1x Sarong (voor tempels – eventueel daar kopen)",
        "1x Pyjama / slaapkleding",
    ],
    "🩳 ZWEM- & SPORTKLEDING": [
        "2x Zwemshorts",
        "1x UV-shirt (voor surfen/snorkelen)",
        "1x Sportoutfit (voor wandelen of yoga)",
    ],
    "👟 SCHOEISEL": [
        "1x Slippers",
        "1x Sneakers of wandelschoenen",
        "(Optioneel) Waterschoenen",
    ],
    "🧼 TOILETTAS": [
        "Tandenborstel + tandpasta",
        "Zonnecrème SPF 30+ (reef safe)",
        "Muggenspray met DEET",
        "Shampoo/bar + zeep",
        "Deodorant",
        "Scheerspullen",
        "EHBO-kitje:",
        "- Pleisters",
        "- Paracetamol",
        "- ORS",
        "- Diarreeremmer",
        "- Wondgel",
    ],
    "⚡ ELEKTRONICA": [
        "Smartphone + oplader",
        "Wereldstekker (type C/F)",
        "Powerbank",
        "(Optioneel) E-reader / koptelefoon / GoPro",
    ],
    "📄 DOCUMENTEN": [
        "Paspoort + kopie (digitaal & papier)",
        "Internationaal rijbewijs",
        "Reisverzekering + boekingen",
        "Bankkaart + creditcard",
        "Contant geld (euro’s – IDR pin je lokaal)",
        "(Optioneel) Vaccinatiebewijs",
    ],
    "🎒 OVERIG": [
        "Kleine dagrugzak",
        "Herbruikbare waterfles (liefst met filter)",
        "Sneldrogende handdoek of hamamdoek",
        "Ziplocks of packing cubes",
        "Waslijntje + mini wasmiddel",
        "Oordopjes + slaapmasker",
        "Zonnebril",
        "Pet of hoed",
    ],
}

# Voeg checklistitems toe aan het document
for category, items in checklist.items():
    doc.add_heading(category, level=2)
    for item in items:
        doc.add_paragraph(f"☐ {item}", style='List Bullet')

# Sla het document op
file_path = "C:\\Temp\\bali_test.docx"
doc.save(file_path)

print(f"Document opgeslagen op: {file_path}")
# Out:
# Document opgeslagen op: C:\Temp\bali_test.docx
